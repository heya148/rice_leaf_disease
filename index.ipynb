# %%
# !pip install ultralytics --upgrade

# %%
# !pip install ultralytics --upgrade

# %%
import sys
# !{sys.executable} -m pip install ultralytics --upgrade
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
import os

path = "/Users/bashir/Desktop/rice_leaf_diseases/rice_leaf_disease.v2i.yolov8/train/images"
print(os.path.exists(path))
# Out:
# True

# %%
import os

path = "/Users/bashir/Desktop/rice_leaf_diseases/rice_leaf_disease.v2i.yolov8/train/images"
print(os.path.exists(path))
# Out:
# True

# %%
print(os.listdir("/Users/bashir/Desktop/rice_leaf_diseases"))
# Out:
# ['.DS_Store', 'rice_leaf_disease.v2i.yolov8', 'index.py', 'rice_leaf_ disease.v2i.yolov8.zip']

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")   # or yolov8s.pt if faster

model.train(
    data="data.yaml",
    epochs=100,
    imgsz=640,
    batch=8,
    workers=2
)
# Out:
# Ultralytics 8.3.234 🚀 Python-3.13.3 torch-2.9.1 CPU (Apple M4)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")
metrics = model.val()   # validation run

print(metrics)
# Out:
# Ultralytics 8.3.234 🚀 Python-3.13.3 torch-2.9.1 CPU (Apple M4)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 157.6±12.9 MB/s, size: 27.4 KB)
# val: Scanning /Users/bashir/Desktop/rice_leaf_diseases/rice_leaf_disease.v2i.yolov8/valid/labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20/20 103.1Kit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 106, len(boxes) = 467. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.2s/it 2.4s6.1s
#                    all         20        467      0.668      0.601       0.65      0.392
# ...

# %%
from IPython.display import Image, display

display(Image(filename='runs/detect/train/results.png'))
